# %% [markdown]
# # CODECLAUSE DATA SCIENCE INTERNSHIP

# %% [markdown]
# #### ALLOCATED PROJECT 2: MARKET BASKET ANALYSIS IN PYTHON USING APRIORI ALGORITHM

# %% [markdown]
# ##### By : TULIKA ROY

# %%
import pandas as pd
import mlxtend
from mlxtend.frequent_patterns import apriori, association_rules

# %% [markdown]
# #### Dataset

# %%
dataset = [ ['Milk','Eggs','Bread','Butter' ],
           ['Milk','Cookies','Butter'],
           ['Milk','Eggs','Cookies','Bread','Butter'],
           ['Cookies','Eggs','Bread'],
           ['Milk','Eggs','Bread'],
           ['Milk','Bread','Butter'],
           ['Eggs','Butter'],
           ['Cookies','Bread','Butter'],
           ['Cookies','Bread','Butter','Eggs']]

# %% [markdown]
# #### Transforming the dataset into a one-hot encoded format

# %%
from mlxtend.preprocessing import TransactionEncoder

# %%
te = TransactionEncoder()
te_ary = te.fit(dataset).transform(dataset)
df = pd.DataFrame(te_ary,columns = te.columns_)

# %%
df
# Out:
#    Bread  Butter  Cookies   Eggs   Milk
# 0   True    True    False   True   True
# 1  False    True     True  False   True
# 2   True    True     True   True   True
# 3   True   False     True   True  False
# 4   True   False    False   True   True
# 5   True    True    False  False   True
# 6  False    True    False   True  False
# 7   True    True     True  False  False
# 8   True    True     True   True  False

# %% [markdown]
# #### Applying the apriori algorithm to find the frequent itemset

# %%
frequent_itemset = apriori(df,min_support=0.3,use_colnames=True)

# %% [markdown]
# #### Generating the association rule

# %%
rules = association_rules(frequent_itemset,metric='confidence',min_threshold=0.5)

# %% [markdown]
# #### Sort the association rule by confidence in descending order

# %%
rules = rules.sort_values(by=['confidence'],ascending=False)

# %% [markdown]
# #### Printing the frequent itemsets

# %%
print('Frequent Itemsets:')
print(frequent_itemset)
# Out:
# Frequent Itemsets:
#      support                  itemsets
# 0   0.777778                   (Bread)
# 1   0.777778                  (Butter)
# 2   0.555556                 (Cookies)
# 3   0.666667                    (Eggs)
# 4   0.555556                    (Milk)
# 5   0.555556           (Butter, Bread)
# 6   0.444444          (Bread, Cookies)
# 7   0.555556             (Bread, Eggs)
# 8   0.444444             (Bread, Milk)
# 9   0.444444         (Butter, Cookies)
# 10  0.444444            (Butter, Eggs)
# 11  0.444444            (Butter, Milk)
# 12  0.333333           (Eggs, Cookies)
# 13  0.333333              (Eggs, Milk)
# 14  0.333333  (Butter, Bread, Cookies)
# 15  0.333333     (Butter, Bread, Eggs)
# 16  0.333333     (Butter, Bread, Milk)
# 17  0.333333    (Bread, Eggs, Cookies)
# 18  0.333333       (Bread, Eggs, Milk)

# %% [markdown]
# #### Printing the association rules

# %%
print("\nAssociation Rules:")
print(rules)
# Out:
# Association Rules:
#           antecedents       consequents  antecedent support  \
# 37       (Eggs, Milk)           (Bread)            0.333333
# 32    (Eggs, Cookies)           (Bread)            0.333333
# 5              (Eggs)           (Bread)            0.666667
# 3           (Cookies)           (Bread)            0.555556
# 7              (Milk)           (Bread)            0.555556
# 9           (Cookies)          (Butter)            0.555556
# 13             (Milk)          (Butter)            0.555556
# 20   (Bread, Cookies)          (Butter)            0.444444
# 19  (Butter, Cookies)           (Bread)            0.444444
# 36      (Bread, Milk)            (Eggs)            0.444444
# 31   (Bread, Cookies)            (Eggs)            0.444444
# 28      (Bread, Milk)          (Butter)            0.444444
# 27     (Butter, Milk)           (Bread)            0.444444
# 23     (Butter, Eggs)           (Bread)            0.444444
# 1             (Bread)          (Butter)            0.777778
# 0            (Butter)           (Bread)            0.777778
# 4             (Bread)            (Eggs)            0.777778
# 11             (Eggs)          (Butter)            0.666667
# 39             (Milk)     (Bread, Eggs)            0.555556
# 18    (Butter, Bread)         (Cookies)            0.555556
# 15          (Cookies)            (Eggs)            0.555556
# 21          (Cookies)   (Butter, Bread)            0.555556
# 22    (Butter, Bread)            (Eggs)            0.555556
# 24      (Bread, Eggs)          (Butter)            0.555556
# 35      (Bread, Eggs)            (Milk)            0.555556
# 26    (Butter, Bread)            (Milk)            0.555556
# 17             (Milk)            (Eggs)            0.555556
# 29             (Milk)   (Butter, Bread)            0.555556
# 30      (Bread, Eggs)         (Cookies)            0.555556
# 34          (Cookies)     (Bread, Eggs)            0.555556
# 6             (Bread)            (Milk)            0.777778
# 2             (Bread)         (Cookies)            0.777778
# 10           (Butter)            (Eggs)            0.777778
# 8            (Butter)         (Cookies)            0.777778
# 12           (Butter)            (Milk)            0.777778
# 33             (Eggs)  (Bread, Cookies)            0.666667
# 25             (Eggs)   (Butter, Bread)            0.666667
# 14             (Eggs)         (Cookies)            0.666667
# 38             (Eggs)     (Bread, Milk)            0.666667
# 16             (Eggs)            (Milk)            0.666667
#
#     consequent support   support  confidence      lift  leverage  conviction  \
# 37            0.777778  0.333333    1.000000  1.285714  0.074074         inf
# 32            0.777778  0.333333    1.000000  1.285714  0.074074         inf
# 5             0.777778  0.555556    0.833333  1.071429  0.037037    1.333333
# 3             0.777778  0.444444    0.800000  1.028571  0.012346    1.111111
# 7             0.777778  0.444444    0.800000  1.028571  0.012346    1.111111
# 9             0.777778  0.444444    0.800000  1.028571  0.012346    1.111111
# 13            0.777778  0.444444    0.800000  1.028571  0.012346    1.111111
# 20            0.777778  0.333333    0.750000  0.964286 -0.012346    0.888889
# 19            0.777778  0.333333    0.750000  0.964286 -0.012346    0.888889
# 36            0.666667  0.333333    0.750000  1.125000  0.037037    1.333333
# 31            0.666667  0.333333    0.750000  1.125000  0.037037    1.333333
# 28            0.777778  0.333333    0.750000  0.964286 -0.012346    0.888889
# 27            0.777778  0.333333    0.750000  0.964286 -0.012346    0.888889
# 23            0.777778  0.333333    0.750000  0.964286 -0.012346    0.888889
# 1             0.777778  0.555556    0.714286  0.918367 -0.049383    0.777778
# 0             0.777778  0.555556    0.714286  0.918367 -0.049383    0.777778
# 4             0.666667  0.555556    0.714286  1.071429  0.037037    1.166667
# 11            0.777778  0.444444    0.666667  0.857143 -0.074074    0.666667
# 39            0.555556  0.333333    0.600000  1.080000  0.024691    1.111111
# 18            0.555556  0.333333    0.600000  1.080000  0.024691    1.111111
# 15            0.666667  0.333333    0.600000  0.900000 -0.037037    0.833333
# 21            0.555556  0.333333    0.600000  1.080000  0.024691    1.111111
# 22            0.666667  0.333333    0.600000  0.900000 -0.037037    0.833333
# 24            0.777778  0.333333    0.600000  0.771429 -0.098765    0.555556
# 35            0.555556  0.333333    0.600000  1.080000  0.024691    1.111111
# 26            0.555556  0.333333    0.600000  1.080000  0.024691    1.111111
# 17            0.666667  0.333333    0.600000  0.900000 -0.037037    0.833333
# 29            0.555556  0.333333    0.600000  1.080000  0.024691    1.111111
# 30            0.555556  0.333333    0.600000  1.080000  0.024691    1.111111
# 34            0.555556  0.333333    0.600000  1.080000  0.024691    1.111111
# 6             0.555556  0.444444    0.571429  1.028571  0.012346    1.037037
# 2             0.555556  0.444444    0.571429  1.028571  0.012346    1.037037
# 10            0.666667  0.444444    0.571429  0.857143 -0.074074    0.777778
# 8             0.555556  0.444444    0.571429  1.028571  0.012346    1.037037
# 12            0.555556  0.444444    0.571429  1.028571  0.012346    1.037037
# 33            0.444444  0.333333    0.500000  1.125000  0.037037    1.111111
# 25            0.555556  0.333333    0.500000  0.900000 -0.037037    0.888889
# 14            0.555556  0.333333    0.500000  0.900000 -0.037037    0.888889
# 38            0.444444  0.333333    0.500000  1.125000  0.037037    1.111111
# 16            0.555556  0.333333    0.500000  0.900000 -0.037037    0.888889
#
#     zhangs_metric
# 37       0.333333
# 32       0.333333
# 5        0.200000
# 3        0.062500
# 7        0.062500
# 9        0.062500
# 13       0.062500
# 20      -0.062500
# 19      -0.062500
# 36       0.200000
# 31       0.200000
# 28      -0.062500
# 27      -0.062500
# 23      -0.062500
# 1       -0.285714
# 0       -0.285714
# 4        0.300000
# 11      -0.333333
# 39       0.166667
# 18       0.166667
# 15      -0.200000
# 21       0.166667
# 22      -0.200000
# 24      -0.400000
# 35       0.166667
# 26       0.166667
# 17      -0.200000
# 29       0.166667
# 30       0.166667
# 34       0.166667
# 6        0.125000
# 2        0.125000
# 10      -0.428571
# 8        0.125000
# 12       0.125000
# 33       0.333333
# 25      -0.250000
# 14      -0.250000
# 38       0.333333
# 16      -0.250000

# %% [markdown]
# ##### Print additional details of the associative rules

# %%
print("\nAssociative Rules Details:")
for i, rule in rules.iterrows():
    antecedents = ','.join(list(rule['antecedents']))
    consequents = ','.join(list(rule['consequents']))
    support = rule['support']
    confidence = rule['confidence']
    lift = rule['lift']
    leverage = rule['leverage']
    conviction = rule['conviction']
    print(f"Rule {i+1}:")
    print(f"Antecedents {antecedents}")

    print(f"Consequents {consequents}")
    print(f"support {support:.3f}")
    print(f"Confidence {confidence:.3f}")
    print(f"Lift {lift:.3f}")
    print(f"Leverage {leverage:.3f}")
    print(f"Conviction {conviction:.3f}")
    print("\n")
# Out:
# Associative Rules Details:
# Rule 38:
# Antecedents Eggs,Milk
# Consequents Bread
# support 0.333
# Confidence 1.000
# Lift 1.286
# Leverage 0.074
# Conviction inf
#
#
# Rule 33:
# Antecedents Eggs,Cookies
# Consequents Bread
# support 0.333
# Confidence 1.000
# Lift 1.286
# Leverage 0.074
# Conviction inf
#
#
# Rule 6:
# Antecedents Eggs
# Consequents Bread
# support 0.556
# Confidence 0.833
# Lift 1.071
# Leverage 0.037
# Conviction 1.333
#
#
# Rule 4:
# Antecedents Cookies
# Consequents Bread
# support 0.444
# Confidence 0.800
# Lift 1.029
# Leverage 0.012
# Conviction 1.111
#
#
# Rule 8:
# Antecedents Milk
# Consequents Bread
# support 0.444
# Confidence 0.800
# Lift 1.029
# Leverage 0.012
# Conviction 1.111
#
#
# Rule 10:
# Antecedents Cookies
# Consequents Butter
# support 0.444
# Confidence 0.800
# Lift 1.029
# Leverage 0.012
# Conviction 1.111
#
#
# Rule 14:
# Antecedents Milk
# Consequents Butter
# support 0.444
# Confidence 0.800
# Lift 1.029
# Leverage 0.012
# Conviction 1.111
#
#
# Rule 21:
# Antecedents Bread,Cookies
# Consequents Butter
# support 0.333
# Confidence 0.750
# Lift 0.964
# Leverage -0.012
# Conviction 0.889
#
#
# Rule 20:
# Antecedents Butter,Cookies
# Consequents Bread
# support 0.333
# Confidence 0.750
# Lift 0.964
# Leverage -0.012
# Conviction 0.889
#
#
# Rule 37:
# Antecedents Bread,Milk
# Consequents Eggs
# support 0.333
# Confidence 0.750
# Lift 1.125
# Leverage 0.037
# Conviction 1.333
#
#
# Rule 32:
# Antecedents Bread,Cookies
# Consequents Eggs
# support 0.333
# Confidence 0.750
# Lift 1.125
# Leverage 0.037
# Conviction 1.333
#
#
# Rule 29:
# Antecedents Bread,Milk
# Consequents Butter
# support 0.333
# Confidence 0.750
# Lift 0.964
# Leverage -0.012
# Conviction 0.889
#
#
# Rule 28:
# Antecedents Butter,Milk
# Consequents Bread
# support 0.333
# Confidence 0.750
# Lift 0.964
# Leverage -0.012
# Conviction 0.889
#
#
# Rule 24:
# Antecedents Butter,Eggs
# Consequents Bread
# support 0.333
# Confidence 0.750
# Lift 0.964
# Leverage -0.012
# Conviction 0.889
#
#
# Rule 2:
# Antecedents Bread
# Consequents Butter
# support 0.556
# Confidence 0.714
# Lift 0.918
# Leverage -0.049
# Conviction 0.778
#
#
# Rule 1:
# Antecedents Butter
# Consequents Bread
# support 0.556
# Confidence 0.714
# Lift 0.918
# Leverage -0.049
# Conviction 0.778
#
#
# Rule 5:
# Antecedents Bread
# Consequents Eggs
# support 0.556
# Confidence 0.714
# Lift 1.071
# Leverage 0.037
# Conviction 1.167
#
#
# Rule 12:
# Antecedents Eggs
# Consequents Butter
# support 0.444
# Confidence 0.667
# Lift 0.857
# Leverage -0.074
# Conviction 0.667
#
#
# Rule 40:
# Antecedents Milk
# Consequents Bread,Eggs
# support 0.333
# Confidence 0.600
# Lift 1.080
# Leverage 0.025
# Conviction 1.111
#
#
# Rule 19:
# Antecedents Butter,Bread
# Consequents Cookies
# support 0.333
# Confidence 0.600
# Lift 1.080
# Leverage 0.025
# Conviction 1.111
#
#
# Rule 16:
# Antecedents Cookies
# Consequents Eggs
# support 0.333
# Confidence 0.600
# Lift 0.900
# Leverage -0.037
# Conviction 0.833
#
#
# Rule 22:
# Antecedents Cookies
# Consequents Butter,Bread
# support 0.333
# Confidence 0.600
# Lift 1.080
# Leverage 0.025
# Conviction 1.111
#
#
# Rule 23:
# Antecedents Butter,Bread
# Consequents Eggs
# support 0.333
# Confidence 0.600
# Lift 0.900
# Leverage -0.037
# Conviction 0.833
#
#
# Rule 25:
# Antecedents Bread,Eggs
# Consequents Butter
# support 0.333
# Confidence 0.600
# Lift 0.771
# Leverage -0.099
# Conviction 0.556
#
#
# Rule 36:
# Antecedents Bread,Eggs
# Consequents Milk
# support 0.333
# Confidence 0.600
# Lift 1.080
# Leverage 0.025
# Conviction 1.111
#
#
# Rule 27:
# Antecedents Butter,Bread
# Consequents Milk
# support 0.333
# Confidence 0.600
# Lift 1.080
# Leverage 0.025
# Conviction 1.111
#
#
# Rule 18:
# Antecedents Milk
# Consequents Eggs
# support 0.333
# Confidence 0.600
# Lift 0.900
# Leverage -0.037
# Conviction 0.833
#
#
# Rule 30:
# Antecedents Milk
# Consequents Butter,Bread
# support 0.333
# Confidence 0.600
# Lift 1.080
# Leverage 0.025
# Conviction 1.111
#
#
# Rule 31:
# Antecedents Bread,Eggs
# Consequents Cookies
# support 0.333
# Confidence 0.600
# Lift 1.080
# Leverage 0.025
# Conviction 1.111
#
#
# Rule 35:
# Antecedents Cookies
# Consequents Bread,Eggs
# support 0.333
# Confidence 0.600
# Lift 1.080
# Leverage 0.025
# Conviction 1.111
#
#
# Rule 7:
# Antecedents Bread
# Consequents Milk
# support 0.444
# Confidence 0.571
# Lift 1.029
# Leverage 0.012
# Conviction 1.037
#
#
# Rule 3:
# Antecedents Bread
# Consequents Cookies
# support 0.444
# Confidence 0.571
# Lift 1.029
# Leverage 0.012
# Conviction 1.037
#
#
# Rule 11:
# Antecedents Butter
# Consequents Eggs
# support 0.444
# Confidence 0.571
# Lift 0.857
# Leverage -0.074
# Conviction 0.778
#
#
# Rule 9:
# Antecedents Butter
# Consequents Cookies
# support 0.444
# Confidence 0.571
# Lift 1.029
# Leverage 0.012
# Conviction 1.037
#
#
# Rule 13:
# Antecedents Butter
# Consequents Milk
# support 0.444
# Confidence 0.571
# Lift 1.029
# Leverage 0.012
# Conviction 1.037
#
#
# Rule 34:
# Antecedents Eggs
# Consequents Bread,Cookies
# support 0.333
# Confidence 0.500
# Lift 1.125
# Leverage 0.037
# Conviction 1.111
#
#
# Rule 26:
# Antecedents Eggs
# Consequents Butter,Bread
# support 0.333
# Confidence 0.500
# Lift 0.900
# Leverage -0.037
# Conviction 0.889
#
#
# Rule 15:
# Antecedents Eggs
# Consequents Cookies
# support 0.333
# Confidence 0.500
# Lift 0.900
# Leverage -0.037
# Conviction 0.889
#
#
# Rule 39:
# Antecedents Eggs
# Consequents Bread,Milk
# support 0.333
# Confidence 0.500
# Lift 1.125
# Leverage 0.037
# Conviction 1.111
#
#
# Rule 17:
# Antecedents Eggs
# Consequents Milk
# support 0.333
# Confidence 0.500
# Lift 0.900
# Leverage -0.037
# Conviction 0.889
